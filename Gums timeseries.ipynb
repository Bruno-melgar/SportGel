# %% [markdown]
# # Importing basic libraries

# %%
import pandas as pd
import plotly.express as px
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go

# %% [markdown]
# # Importing Dataset

# %%
# Import data
df = pd.read_excel('gumts.xlsx')

# %% [markdown]
# # Data Wrangling

# %%
# data glimpse
df.shape
# Out:
# (242, 14)

# %%
# data glimpse
df.dtypes
# Out:
# Replicate                       int64
# time                            int64
# Gum                            object
# Concent                       float64
# Rep                             int64
# Code                           object
# Firmness (g)                  float64
# Consistency (g.sec)           float64
# Cohesiveness (g)              float64
# Index of Viscosity (g.sec)    float64
# viscosity (mPa.s)              object
# gum stirring time (min)       float64
# heat at mix?                   object
# temp of test                  float64
# dtype: object

# %% [markdown]
# # Subset Firmness

# %%
# Remove of specified columns
df = df.drop(df.columns[[0, 4, 5, 11, 12, 13]], axis=1)

# Select predictors and firmness response
df = df.iloc[:, :4]

# Columns rename
df.columns = ["time", "gum", "concent", "firmness"]
# Out:
# Index(['time', 'Gum', 'Concent', 'Firmness (g)'], dtype='object')

# %%
# df head
print(df.head())
# Out:
#    time  gum  concent  firmness
# 0     0  xan     0.50      15.8
# 1     0  xan     0.50      15.5
# 2     0  xan     1.25      33.2
# 3     0  xan     1.25      32.4
# 4     0  xan     2.25      59.1

# %%
# Remove specific observations
df = df[~df['gum'].isin(["Dextrose+xant", "Honey+xant"])]
df['gum'].unique()
# Out:
# array(['xan', 'gua', 'loc', 'car', 'gel'], dtype=object)

# %%
# Pivoting DataFrame
pivot_df = df.pivot_table(index=['gum', 'concent'],
                           columns='time',
                           values='firmness').reset_index()
pivot_df.head()
# Out:
# time  gum  concent      0         1          2          3
# 0     car     0.50   9.25    9.4250   9.500000   9.533333
# 1     car     1.25   9.75    9.7250  10.000000  10.066667
# 2     car     2.25  21.30   18.7000  13.600000  12.466667
# 3     car     3.00  97.50  115.7500  87.966667  65.766667
# 4     gel     0.50   9.55    9.0575   9.066667   9.000000

# %%
print("Columns in pivot_df:", pivot_df.columns.tolist())
# Out:
# Columnas actuales en pivot_df: ['gum', 'concent', 0, 1, 2, 3]

# %%
# Rename columns '0', '1', '2', '3' a 't0', 't1', 't2', 't3'
pivot_df.rename(columns={0: 't0', 1: 't1', 2: 't2', 3: 't3'}, inplace=True)

# DataFrame Head
print(pivot_df.head())
# Out:
# time  gum  concent     t0        t1         t2         t3
# 0     car     0.50   9.25    9.4250   9.500000   9.533333
# 1     car     1.25   9.75    9.7250  10.000000  10.066667
# 2     car     2.25  21.30   18.7000  13.600000  12.466667
# 3     car     3.00  97.50  115.7500  87.966667  65.766667
# 4     gel     0.50   9.55    9.0575   9.066667   9.000000

# %%
pivot_df['gum_code'] = pivot_df['gum'].astype('category').cat.codes

# %%
# adding 5 unique category codes for 'gum'
unique_categories = pivot_df['gum'].unique()
desired_codes = [0, 0.2, 0.4, 0.6, 0.8]

# Mapping category codes
mapping_dict = dict(zip(unique_categories, desired_codes))

# Apply mapping to 'gum_code'
pivot_df['gum_code'] = pivot_df['gum'].map(mapping_dict)

# show
pivot_df
# Out:
# time  gum  concent      t0        t1          t2          t3  gum_code
# 0     car     0.50    9.25    9.4250    9.500000    9.533333       0.0
# 1     car     1.25    9.75    9.7250   10.000000   10.066667       0.0
# 2     car     2.25   21.30   18.7000   13.600000   12.466667       0.0
# 3     car     3.00   97.50  115.7500   87.966667   65.766667       0.0
# 4     gel     0.50    9.55    9.0575    9.066667    9.000000       0.2
# 5     gel     1.25   11.85   10.5750    9.566667    9.666667       0.2
# 6     gel     2.25   35.85   26.0000   22.333333   26.100000       0.2
# 7     gel     3.00   70.05   52.8500   61.500000   53.833333       0.2
# 8     gua     0.50    9.75   10.0000   10.066667   10.333333       0.4
# 9     gua     1.25   20.20   32.0250   30.466667   16.433333       0.4
# 10    gua     2.25  154.10  188.6500  126.166667   59.766667       0.4
# 11    gua     3.00  200.70  292.8000  262.733333  104.633333       0.4
# 12    loc     0.50    9.35    9.2500    9.333333    9.100000       0.6
# 13    loc     1.25    9.50    9.8250   10.133333   10.233333       0.6
# 14    loc     2.25   11.40   15.1250   18.866667   27.033333       0.6
# 15    loc     3.00   24.90   31.7000   28.566667   34.966667       0.6
# 16    xan     0.50   15.65   15.5250   15.833333   16.700000       0.8
# 17    xan     1.25   32.80   29.7500   28.933333   30.333333       0.8
# 18    xan     2.25   58.40   53.2750   48.766667   51.966667       0.8
# 19    xan     3.00   89.25   81.9500   77.466667   70.500000       0.8

# %%
# Repeat the DataFrame 10 times to make plot lines bolder
pivot_df = pd.concat([pivot_df] * 10, ignore_index=True)

# Display the result
pivot_df
# Out:
# time  gum  concent     t0        t1         t2         t3  gum_code
# 0     car     0.50   9.25    9.4250   9.500000   9.533333       0.0
# 1     car     1.25   9.75    9.7250  10.000000  10.066667       0.0
# 2     car     2.25  21.30   18.7000  13.600000  12.466667       0.0
# 3     car     3.00  97.50  115.7500  87.966667  65.766667       0.0
# 4     gel     0.50   9.55    9.0575   9.066667   9.000000       0.2
# ..    ...      ...    ...       ...        ...        ...       ...
# 195   loc     3.00  24.90   31.7000  28.566667  34.966667       0.6
# 196   xan     0.50  15.65   15.5250  15.833333  16.700000       0.8
# 197   xan     1.25  32.80   29.7500  28.933333  30.333333       0.8
# 198   xan     2.25  58.40   53.2750  48.766667  51.966667       0.8
# 199   xan     3.00  89.25   81.9500  77.466667  70.500000       0.8
#
# [200 rows x 7 columns]

# %% [markdown]
# ### Plotting

# %%
# Original parallel coordinates plot

fig = px.parallel_coordinates(pivot_df, color="gum_code",
                              dimensions=['concent', 't0', 't1', 't2', 't3'],
                              color_continuous_scale=px.colors.diverging.Tealrose,
                              labels={"concent": "Concentration",
                                      "t0": "Time 0",
                                      "t1": "Time 1",
                                      "t2": "Time 2",
                                      "t3": "Time 3",
                                      "gum_code": "Gum Code"},
                              title="Firmess (g) of gums tested over time")

fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="66755aa4-b91b-499e-8e9b-623aec11751f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("66755aa4-b91b-499e-8e9b-623aec11751f")) {                    Plotly.newPlot(                        "66755aa4-b91b-499e-8e9b-623aec11751f",                        [{"dimensions":[{"label":"Concentration","values":[0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0]},{"label":"Time 0","values":[9.25,9.75,21.3,97.5,9.55,11.85,35.85,70.05,9.75,20.2,154.1,200.7,9.350000000000001,9.5,11.399999999999999,24.9,15.65,32.8,58.400000000000006,89.25]},{"label":"Time 1","values":[9.425,9.725,18.7,115.75,9.057500000000001,10.575,26.0,52.85,10.0,32.025,188.64999999999998,292.8,9.25,9.825,15.125,31.7,15.525,29.75,53.275,81.95]},{"label":"Time 2","values":[9.5,10.0,13.6,87.96666666666665,9.066666666666668,9.566666666666666,22.333333333333332,61.5,10.066666666666666,30.46666666666667,126.16666666666667,262.73333333333335,9.333333333333334,10.133333333333333,18.866666666666667,28.566666666666666,15.833333333333334,28.933333333333334,48.76666666666667,77.46666666666667]},{"label":"Time 3","values":[9.533333333333333,10.066666666666668,12.466666666666667,65.76666666666667,9.0,9.666666666666666,26.099999999999998,53.833333333333336,10.333333333333334,16.433333333333334,59.76666666666667,104.63333333333334,9.1,10.233333333333334,27.03333333333333,34.96666666666667,16.7,30.333333333333332,51.96666666666667,70.5]}],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"line":{"color":[0.0,0.0,0.0,0.0,0.2,0.2,0.2,0.2,0.4,0.4,0.4,0.4,0.6,0.6,0.6,0.6,0.8,0.8,0.8,0.8],"coloraxis":"coloraxis"},"name":"","type":"parcoords"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"] ...

# %%
# export fig as html
fig.write_html("Firmness_Times_Bold.html")

# %% [markdown]
# ### Plot styling

# %%
fig = go.Figure(data=
    go.Parcoords(
        line = dict(color = pivot_df['gum_code'],
                   colorscale = "Tealrose"),
        dimensions = list([
            dict(range = [0.5, 3],
                label = 'Gum Concentration (%)', values = pivot_df['concent']),
            dict(range = [9, 300],
                label = 'Time 0', values = pivot_df['t0']),
            dict(range = [9, 300],
                label = 'Time 1', values = pivot_df['t1']),
            dict(range = [9, 300],
                label = 'Time 2', values = pivot_df['t2']),
            dict(range = [9, 300],
                label = 'Time 3', values = pivot_df['t3']),
        ])
    )
)

fig.update_layout(
    plot_bgcolor = 'white',
    paper_bgcolor = 'white',
    title_text="Firmess (g) of gums tested over time"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="98e136c9-44aa-425f-8aca-8df691042d9e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98e136c9-44aa-425f-8aca-8df691042d9e")) {                    Plotly.newPlot(                        "98e136c9-44aa-425f-8aca-8df691042d9e",                        [{"dimensions":[{"label":"Gum Concentration (%)","range":[0.5,3],"values":[0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0]},{"label":"Time 0","range":[9,300],"values":[9.25,9.75,21.3,97.5,9.55,11.85,35.85,70.05,9.75,20.2,154.1,200.7,9.350000000000001,9.5,11.399999999999999,24.9,15.65,32.8,58.400000000000006,89.25,9.25,9.75,21.3,97.5,9.55,11.85,35.85,70.05,9.75,20.2,154.1,200.7,9.350000000000001,9.5,11.399999999999999,24.9,15.65,32.8,58.400000000000006,89.25,9.25,9.75,21.3,97.5,9.55,11.85,35.85,70.05,9.75,20.2,154.1,200.7,9.350000000000001,9.5,11.399999999999999,24.9,15.65,32.8,58.400000000000006,89.25,9.25,9.75,21.3,97.5,9.55,11.85,35.85,70.05,9.75,20.2,154.1,200.7,9.350000000000001,9.5,11.399999999999999,24.9,15.65,32.8,58.400000000000006,89.25,9.25,9.75,21.3,97.5,9.55,11.85,35.85,70.05,9.75,20.2,154.1,200.7,9.350000000000001,9.5,11.399999999999999,24.9,15.65,32.8,58.400000000000006,89.25,9.25,9.75,21.3,97.5,9.55,11.85,35.85,70.05,9.75,20.2,154.1,200.7,9.350000000000001,9.5,11.399999999999999,24.9,15.65,32.8,58.400000000000006,89.25,9.25,9.75,21.3,97.5,9.55,11.85,35.85,70.05,9.75,20.2,154.1,200.7,9.350000000000001,9.5,11.399999999999999,24.9,15.65,32.8,58.400000000000006,89.25,9.25,9.75,21.3,97.5,9.55,11.85,35.85,70.05,9.75,20.2,154.1,200.7,9.350000000000001,9.5,11.399999999999999,24.9,15.65,32.8,58.400000000000006,89.25,9.25,9.75,21.3,97.5,9.55,11.85,35.85,70.05,9.75,20.2,154.1,200.7,9.350000000000001,9.5,11.399999999999999,24.9,15.65,32.8,58.400000000000006,89.25,9.25,9.75,21.3,97.5,9.55,11.85,35.85,70.05,9.75,20.2,154.1,200.7,9.350000000000001,9.5,11.399999999999999,24.9,15.65,32.8,58.400000000000006,89.25]},{"label":"Time 1","range":[9,300],"values":[9.425,9.725,18.7,115.75,9.057500000000001,10.575,26.0,52.85,10.0,32.025,188.64999999999998,292.8,9.25,9.825,15.125,31.7,15.525,29.75,53.275,81.95,9.425,9.725,18.7,115.75,9.057500000000001,10.575,26.0,52.85,10.0,32.025,188.64999999999998,292.8,9.25,9.825,15.125,31.7,15.525,29.75,53.275,81.95,9.425,9.725,18.7,115.75,9.057500000000001,10.575,26.0,52.85,10.0,32.025,188.64999999999998,292.8,9.25,9.825,15.125,31.7,15.525,29.75,53.275,81.95,9.425,9.725,18.7,115.75,9.057500000000001,10.575,26.0,52.85,10.0,32.025,188.64999999999998,292.8,9.25,9.825,15.125,31.7,15.525,29.75,53.275,81.95,9.425,9.725,18.7,115.75,9.057500000000001,10.575,26.0,52.85,10.0,32.025,188.64999999999998,292.8,9.25,9.825,15.125,31.7,15.525,29.75,53.275,81.95,9.425,9.725,18.7,115.75,9.057500000000001,10.575,26.0,52.85,10.0,32.025,188.64999999999998,292.8,9.25,9.825,15.125,31.7,15.525,29.75,53.275,81.95,9.425,9.725,18.7,115.75, ...

# %%
# export fig as html
fig.write_html("parallel_coordinates_plot.html")

# %% [markdown]
# # Subset Consistency

# %%
# Import data
df = pd.read_excel('gumts.xlsx')

# Remove of specified columns
df = df.drop(df.columns[[0, 4, 5, 11, 12, 13]], axis=1)

# Select predictors and firmness response
df = df.iloc[:, [0, 1, 2, 4]]

# Columns rename
df.columns = ["time", "gum", "concent", "consistency"]
# Out:
# Index(['time', 'Gum', 'Concent', 'Consistency (g.sec)'], dtype='object')

# %%
# df head
print(df.head())
# Out:
#    time  gum  concent  consistency
# 0     0  xan     0.50        171.0
# 1     0  xan     0.50        169.4
# 2     0  xan     1.25        306.6
# 3     0  xan     1.25        294.8
# 4     0  xan     2.25        513.3

# %%
# Remove specific observations
df = df[~df['gum'].isin(["Dextrose+xant", "Honey+xant"])]
df['gum'].unique()
# Out:
# array(['xan', 'gua', 'loc', 'car', 'gel'], dtype=object)

# %%
# Pivoting DataFrame
pivot_df = df.pivot_table(index=['gum', 'concent'],
                           columns='time',
                           values='consistency').reset_index()
pivot_df.head()
# Out:
# time  gum  concent        0         1           2           3
# 0     car     0.50  130.615  143.0250  153.200000  150.400000
# 1     car     1.25  131.700  156.9725  163.333333  159.366667
# 2     car     2.25  190.450  182.0500  178.666667  172.000000
# 3     car     3.00  853.850  834.0000  794.466667  541.700000
# 4     gel     0.50  145.450  142.2100  111.800000  146.733333

# %%
print("Columns in pivot_df:", pivot_df.columns.tolist())
# Out:
# Columns in pivot_df: ['gum', 'concent', 0, 1, 2, 3]

# %%
# Rename columns '0', '1', '2', '3' a 't0', 't1', 't2', 't3'
pivot_df.rename(columns={0: 't0', 1: 't1', 2: 't2', 3: 't3'}, inplace=True)

# DataFrame Head
print(pivot_df.head())
# Out:
# time  gum  concent       t0        t1          t2          t3
# 0     car     0.50  130.615  143.0250  153.200000  150.400000
# 1     car     1.25  131.700  156.9725  163.333333  159.366667
# 2     car     2.25  190.450  182.0500  178.666667  172.000000
# 3     car     3.00  853.850  834.0000  794.466667  541.700000
# 4     gel     0.50  145.450  142.2100  111.800000  146.733333

# %%
pivot_df['gum_code'] = pivot_df['gum'].astype('category').cat.codes

# %%
# adding 5 unique category codes for 'gum'
unique_categories = pivot_df['gum'].unique()
desired_codes = [0, 0.2, 0.4, 0.6, 0.8]

# Mapping category codes
mapping_dict = dict(zip(unique_categories, desired_codes))

# Apply mapping to 'gum_code'
pivot_df['gum_code'] = pivot_df['gum'].map(mapping_dict)

# show
pivot_df
# Out:
# time  gum  concent        t0         t1           t2          t3  gum_code
# 0     car     0.50   130.615   143.0250   153.200000  150.400000       0.0
# 1     car     1.25   131.700   156.9725   163.333333  159.366667       0.0
# 2     car     2.25   190.450   182.0500   178.666667  172.000000       0.0
# 3     car     3.00   853.850   834.0000   794.466667  541.700000       0.0
# 4     gel     0.50   145.450   142.2100   111.800000  146.733333       0.2
# 5     gel     1.25   152.400   153.9500   151.466667  158.933333       0.2
# 6     gel     2.25   316.300   209.9500   213.400000   85.033333       0.2
# 7     gel     3.00   592.400   425.0500   412.833333  292.543333       0.2
# 8     gua     0.50   133.450   140.2000   147.333333  136.166667       0.4
# 9     gua     1.25   176.100   264.8750   236.066667  161.000000       0.4
# 10    gua     2.25  1239.650  1361.8500   936.433333  465.166667       0.4
# 11    gua     3.00  1633.200  1972.2500  1885.600000  762.500000       0.4
# 12    loc     0.50   135.150   143.2250   105.053333  146.300000       0.6
# 13    loc     1.25   134.950   148.3500   162.466667  158.966667       0.6
# 14    loc     2.25   130.000   163.0750   164.933333  230.533333       0.6
# 15    loc     3.00   232.900   272.6750   244.666667  143.533333       0.6
# 16    xan     0.50   170.200   157.9000   166.766667  193.166667       0.8
# 17    xan     1.25   300.700   263.5000   263.033333  279.400000       0.8
# 18    xan     2.25   503.650   448.9000   425.966667  457.466667       0.8
# 19    xan     3.00   724.150   646.0250   639.933333  579.896667       0.8

# %%
# Repeat the DataFrame 10 times to make plot lines bolder
pivot_df = pd.concat([pivot_df] * 10, ignore_index=True)

# Display the result
pivot_df
# Out:
# time  gum  concent       t0        t1          t2          t3  gum_code
# 0     car     0.50  130.615  143.0250  153.200000  150.400000       0.0
# 1     car     1.25  131.700  156.9725  163.333333  159.366667       0.0
# 2     car     2.25  190.450  182.0500  178.666667  172.000000       0.0
# 3     car     3.00  853.850  834.0000  794.466667  541.700000       0.0
# 4     gel     0.50  145.450  142.2100  111.800000  146.733333       0.2
# ..    ...      ...      ...       ...         ...         ...       ...
# 195   loc     3.00  232.900  272.6750  244.666667  143.533333       0.6
# 196   xan     0.50  170.200  157.9000  166.766667  193.166667       0.8
# 197   xan     1.25  300.700  263.5000  263.033333  279.400000       0.8
# 198   xan     2.25  503.650  448.9000  425.966667  457.466667       0.8
# 199   xan     3.00  724.150  646.0250  639.933333  579.896667       0.8
#
# [200 rows x 7 columns]

# %% [markdown]
# ### Plotting

# %%
fig = go.Figure(data=
    go.Parcoords(
        line = dict(color = pivot_df['gum_code'],
                   colorscale = "Tealrose"),
        dimensions = list([
            dict(range = [0.5, 3],
                label = 'Gum Concentration (%)', values = pivot_df['concent']),
            dict(range = [9, 2000],
                label = 'Time 0', values = pivot_df['t0']),
            dict(range = [9, 2000],
                label = 'Time 1', values = pivot_df['t1']),
            dict(range = [9, 2000],
                label = 'Time 2', values = pivot_df['t2']),
            dict(range = [9, 2000],
                label = 'Time 3', values = pivot_df['t3']),
        ])
    )
)

fig.update_layout(
    plot_bgcolor = 'white',
    paper_bgcolor = 'white',
    title_text="Consistency (g/s) of gums tested over time"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="79007021-41f3-4ef6-8cb2-e9eccf72df3f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("79007021-41f3-4ef6-8cb2-e9eccf72df3f")) {                    Plotly.newPlot(                        "79007021-41f3-4ef6-8cb2-e9eccf72df3f",                        [{"dimensions":[{"label":"Gum Concentration (%)","range":[0.5,3],"values":[0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0]},{"label":"Time 0","range":[9,2000],"values":[-4.615,-6.9,-53.8,-439.04999999999995,-4.4,-8.75,-111.4,-336.75,-6.665,-52.400000000000006,-980.1999999999999,-1164.3,-4.835,-5.800000000000001,-12.55,-58.9,-15.4,-88.44999999999999,-240.45,-357.95,-4.615,-6.9,-53.8,-439.04999999999995,-4.4,-8.75,-111.4,-336.75,-6.665,-52.400000000000006,-980.1999999999999,-1164.3,-4.835,-5.800000000000001,-12.55,-58.9,-15.4,-88.44999999999999,-240.45,-357.95,-4.615,-6.9,-53.8,-439.04999999999995,-4.4,-8.75,-111.4,-336.75,-6.665,-52.400000000000006,-980.1999999999999,-1164.3,-4.835,-5.800000000000001,-12.55,-58.9,-15.4,-88.44999999999999,-240.45,-357.95,-4.615,-6.9,-53.8,-439.04999999999995,-4.4,-8.75,-111.4,-336.75,-6.665,-52.400000000000006,-980.1999999999999,-1164.3,-4.835,-5.800000000000001,-12.55,-58.9,-15.4,-88.44999999999999,-240.45,-357.95,-4.615,-6.9,-53.8,-439.04999999999995,-4.4,-8.75,-111.4,-336.75,-6.665,-52.400000000000006,-980.1999999999999,-1164.3,-4.835,-5.800000000000001,-12.55,-58.9,-15.4,-88.44999999999999,-240.45,-357.95,-4.615,-6.9,-53.8,-439.04999999999995,-4.4,-8.75,-111.4,-336.75,-6.665,-52.400000000000006,-980.1999999999999,-1164.3,-4.835,-5.800000000000001,-12.55,-58.9,-15.4,-88.44999999999999,-240.45,-357.95,-4.615,-6.9,-53.8,-439.04999999999995,-4.4,-8.75,-111.4,-336.75,-6.665,-52.400000000000006,-980.1999999999999,-1164.3,-4.835,-5.800000000000001,-12.55,-58.9,-15.4,-88.44999999999999,-240.45,-357.95,-4.615,-6.9,-53.8,-439.04999999999995,-4.4,-8.75,-111.4,-336.75,-6.665,-52.400000000000006,-980.1999999999999,-1164.3,-4.835,-5.800000000000001,-12.55,-58.9,-15.4,-88.44999999999999,-240.45,-357.95,-4.615,-6.9,-53.8,-439.04999999999995,-4.4,-8.75,-111.4,-336.75,-6.665,-52.400000000000006,-980.1999999999999,-1164.3,-4.835,-5.800000000000001,-12.55,-58.9,-15.4,-88.44999999999999,-240.45,-357.95,-4.615,-6.9,-53.8,-439.04999999999995,-4.4,-8.75,-111.4,-336.75,-6.665,-52.400000000000006,-980.1999999999999,-1164.3,-4.835,-5.800000000000001,-12.55,-58.9,-15.4,-88.44999999999999,-240.45,-357.95]},{"label":"Time 1","range":[9,2000],"values":[-4.825,-4.225,-17.35,-259.8,-4.025,-5.925,-39.675,-199.35,-6.9575,-105.5,-953.0,-1404.925,-4.775,-6.35,-9.625,-112.325,-17.575,-79.25,-220.35000000000002,-349.8,-4.825,-4.225,-17.35,-259.8,-4.025,-5.925,-39.675,-199.35,-6.9575,-105.5,-953.0,-1404.925,-4.775,-6.35,-9.625,-112.325,-17.575,-79.25,-220.35000000000002,-349.8,-4.825,-4.225,-17.35,-259.8,-4.025,-5.925,-39.675,-199.35,-6.9575, ...

# %%
# export fig as html
fig.write_html("Consistency_Times_Bold.html")

# %% [markdown]
# # Subset Cohesiveness

# %%
# Import data
df = pd.read_excel('gumts.xlsx')

# Remove of specified columns
df = df.drop(df.columns[[0, 4, 5, 11, 12, 13]], axis=1)

# Select predictors and firmness response
df = df.iloc[:, [0, 1, 2, 5]]

# Show column names
print(df.columns)

# Columns rename
df.columns = ["time", "gum", "concent", "cohesiveness"]
# Out:
# Index(['time', 'Gum', 'Concent', 'Cohesiveness (g)'], dtype='object')

# %%
# df head
print(df.head())
# Out:
#    time  gum  concent  cohesiveness
# 0     0  xan     0.50          -8.9
# 1     0  xan     0.50          -9.0
# 2     0  xan     1.25         -16.6
# 3     0  xan     1.25         -17.0
# 4     0  xan     2.25         -29.8

# %%
# Remove specific observations
df = df[~df['gum'].isin(["Dextrose+xant", "Honey+xant"])]
df['gum'].unique()
# Out:
# array(['xan', 'gua', 'loc', 'car', 'gel'], dtype=object)

# %%
# Pivoting DataFrame
pivot_df = df.pivot_table(index=['gum', 'concent'],
                           columns='time',
                           values='cohesiveness').reset_index()
pivot_df.head()
# Out:
# time  gum  concent       0      1          2          3
# 0     car     0.50  -5.535  -5.55  -5.366667  -4.766667
# 1     car     1.25  -6.750  -2.35  -5.600000  -4.333333
# 2     car     2.25 -13.300  -8.75 -30.300000  -6.176667
# 3     car     3.00 -57.950 -40.95 -41.033333 -28.900000
# 4     gel     0.50  -5.150  -5.15  -5.966667  -4.800000

# %%
print("Columns in pivot_df:", pivot_df.columns.tolist())
# Out:
# Columns in pivot_df: ['gum', 'concent', 0, 1, 2, 3]

# %%
# Renombrar las columnas '0', '1', '2', '3' a 't0', 't1', 't2', 't3'
pivot_df.rename(columns={0: 't0', 1: 't1', 2: 't2', 3: 't3'}, inplace=True)

# Mostrar el nuevo DataFrame
print(pivot_df.head())
# Out:
# time  gum  concent      t0     t1         t2         t3
# 0     car     0.50  -5.535  -5.55  -5.366667  -4.766667
# 1     car     1.25  -6.750  -2.35  -5.600000  -4.333333
# 2     car     2.25 -13.300  -8.75 -30.300000  -6.176667
# 3     car     3.00 -57.950 -40.95 -41.033333 -28.900000
# 4     gel     0.50  -5.150  -5.15  -5.966667  -4.800000

# %%
pivot_df['gum_code'] = pivot_df['gum'].astype('category').cat.codes

# %%
# adding 5 unique category codes for 'gum'
unique_categories = pivot_df['gum'].unique()
desired_codes = [0, 0.2, 0.4, 0.6, 0.8]

# Mapping category codes
mapping_dict = dict(zip(unique_categories, desired_codes))

# Apply mapping to 'gum_code'
pivot_df['gum_code'] = pivot_df['gum'].map(mapping_dict)

# show
pivot_df
# Out:
# time  gum  concent       t0       t1          t2         t3  gum_code
# 0     car     0.50   -5.535   -5.550   -5.366667  -4.766667       0.0
# 1     car     1.25   -6.750   -2.350   -5.600000  -4.333333       0.0
# 2     car     2.25  -13.300   -8.750  -30.300000  -6.176667       0.0
# 3     car     3.00  -57.950  -40.950  -41.033333 -28.900000       0.0
# 4     gel     0.50   -5.150   -5.150   -5.966667  -4.800000       0.2
# 5     gel     1.25   -6.900   -5.900   -5.733333  -5.266667       0.2
# 6     gel     2.25  -20.200  -10.725   -8.700000 -10.533333       0.2
# 7     gel     3.00  -44.850  -27.800  -50.500000 -26.166667       0.2
# 8     gua     0.50   -6.480   -6.475   -6.666667  -4.066667       0.4
# 9     gua     1.25  -12.450  -16.380  -10.866667  -8.033333       0.4
# 10    gua     2.25 -121.250 -126.025  -90.100000 -31.333333       0.4
# 11    gua     3.00 -161.300 -171.050 -161.666667 -55.466667       0.4
# 12    loc     0.50   -5.600   -5.550   -5.200000  -4.833333       0.6
# 13    loc     1.25   -6.250   -6.025   -5.500000  -5.233333       0.6
# 14    loc     2.25   -8.485   -6.875   -7.566667 -11.033333       0.6
# 15    loc     3.00  -12.475  -16.425  -12.233333  -7.100000       0.6
# 16    xan     0.50   -8.950   -9.525   -9.233333  -7.866667       0.8
# 17    xan     1.25  -16.800  -16.475  -15.733333 -10.933333       0.8
# 18    xan     2.25  -30.100  -28.650  -26.666667 -87.200000       0.8
# 19    xan     3.00  -45.350  -42.700  -40.033333 -29.800000       0.8

# %%
# Repeat the DataFrame 10 times to make plot lines bolder
pivot_df = pd.concat([pivot_df] * 10, ignore_index=True)

# Display the result
pivot_df
# Out:
# time  gum  concent      t0      t1         t2         t3  gum_code
# 0     car     0.50  -5.535  -5.550  -5.366667  -4.766667       0.0
# 1     car     1.25  -6.750  -2.350  -5.600000  -4.333333       0.0
# 2     car     2.25 -13.300  -8.750 -30.300000  -6.176667       0.0
# 3     car     3.00 -57.950 -40.950 -41.033333 -28.900000       0.0
# 4     gel     0.50  -5.150  -5.150  -5.966667  -4.800000       0.2
# ..    ...      ...     ...     ...        ...        ...       ...
# 195   loc     3.00 -12.475 -16.425 -12.233333  -7.100000       0.6
# 196   xan     0.50  -8.950  -9.525  -9.233333  -7.866667       0.8
# 197   xan     1.25 -16.800 -16.475 -15.733333 -10.933333       0.8
# 198   xan     2.25 -30.100 -28.650 -26.666667 -87.200000       0.8
# 199   xan     3.00 -45.350 -42.700 -40.033333 -29.800000       0.8
#
# [200 rows x 7 columns]

# %% [markdown]
# ### Plotting

# %%
fig = go.Figure(data=
    go.Parcoords(
        line = dict(color = pivot_df['gum_code'],
                   colorscale = "Tealrose"),
        dimensions = list([
            dict(range = [0.5, 3],
                label = 'Gum Concentration (%)', values = pivot_df['concent']),
            dict(range = [-172, -2],
                label = 'Time 0', values = pivot_df['t0']),
            dict(range = [-172, -2],
                label = 'Time 1', values = pivot_df['t1']),
            dict(range = [-172, -2],
                label = 'Time 2', values = pivot_df['t2']),
            dict(range = [-172, -2],
                label = 'Time 3', values = pivot_df['t3']),
        ])
    )
)

fig.update_layout(
    plot_bgcolor = 'white',
    paper_bgcolor = 'white',
    title_text="Cohesiveness (g) of gums tested over time"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="70ab8516-8fb6-4e53-96d1-80c5b7da638b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("70ab8516-8fb6-4e53-96d1-80c5b7da638b")) {                    Plotly.newPlot(                        "70ab8516-8fb6-4e53-96d1-80c5b7da638b",                        [{"dimensions":[{"label":"Gum Concentration (%)","range":[0.5,3],"values":[0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0]},{"label":"Time 0","range":[-172,-2],"values":[-5.535,-6.75,-13.3,-57.95,-5.15,-6.9,-20.2,-44.849999999999994,-6.48,-12.45,-121.25,-161.3,-5.6,-6.25,-8.485,-12.475000000000001,-8.95,-16.8,-30.1,-45.35,-5.535,-6.75,-13.3,-57.95,-5.15,-6.9,-20.2,-44.849999999999994,-6.48,-12.45,-121.25,-161.3,-5.6,-6.25,-8.485,-12.475000000000001,-8.95,-16.8,-30.1,-45.35,-5.535,-6.75,-13.3,-57.95,-5.15,-6.9,-20.2,-44.849999999999994,-6.48,-12.45,-121.25,-161.3,-5.6,-6.25,-8.485,-12.475000000000001,-8.95,-16.8,-30.1,-45.35,-5.535,-6.75,-13.3,-57.95,-5.15,-6.9,-20.2,-44.849999999999994,-6.48,-12.45,-121.25,-161.3,-5.6,-6.25,-8.485,-12.475000000000001,-8.95,-16.8,-30.1,-45.35,-5.535,-6.75,-13.3,-57.95,-5.15,-6.9,-20.2,-44.849999999999994,-6.48,-12.45,-121.25,-161.3,-5.6,-6.25,-8.485,-12.475000000000001,-8.95,-16.8,-30.1,-45.35,-5.535,-6.75,-13.3,-57.95,-5.15,-6.9,-20.2,-44.849999999999994,-6.48,-12.45,-121.25,-161.3,-5.6,-6.25,-8.485,-12.475000000000001,-8.95,-16.8,-30.1,-45.35,-5.535,-6.75,-13.3,-57.95,-5.15,-6.9,-20.2,-44.849999999999994,-6.48,-12.45,-121.25,-161.3,-5.6,-6.25,-8.485,-12.475000000000001,-8.95,-16.8,-30.1,-45.35,-5.535,-6.75,-13.3,-57.95,-5.15,-6.9,-20.2,-44.849999999999994,-6.48,-12.45,-121.25,-161.3,-5.6,-6.25,-8.485,-12.475000000000001,-8.95,-16.8,-30.1,-45.35,-5.535,-6.75,-13.3,-57.95,-5.15,-6.9,-20.2,-44.849999999999994,-6.48,-12.45,-121.25,-161.3,-5.6,-6.25,-8.485,-12.475000000000001,-8.95,-16.8,-30.1,-45.35,-5.535,-6.75,-13.3,-57.95,-5.15,-6.9,-20.2,-44.849999999999994,-6.48,-12.45,-121.25,-161.3,-5.6,-6.25,-8.485,-12.475000000000001,-8.95,-16.8,-30.1,-45.35]},{"label":"Time 1","range":[-172,-2],"values":[-5.55,-2.35,-8.75,-40.95,-5.15,-5.9,-10.725,-27.8,-6.475,-16.380000000000003,-126.025,-171.05,-5.55,-6.025,-6.875,-16.425,-9.525,-16.475,-28.65,-42.7,-5.55,-2.35,-8.75,-40.95,-5.15,-5.9,-10.725,-27.8,-6.475,-16.380000000000003,-126.025,-171.05,-5.55,-6.025,-6.875,-16.425,-9.525,-16.475,-28.65,-42.7,-5.55,-2.35,-8.75,-40.95,-5.15,-5.9,-10.725,-27.8,-6.475,-16.380000000000003,-126.025,-171.05,-5.55,-6.025,-6.875,-16.425,-9.525,-16.475,-28.65,-42.7,-5.55,-2.35,-8.75,-40.95,-5.15,-5.9,-10.725,-27.8,-6.475,-16.380000000000003,-126.025,-171.05,-5.55,-6.025,-6.875,-16.425,-9.525,-16.475,-28.65,-42.7,-5.55,-2.35,-8.75,-40.95,-5.15,-5.9,-10.725,-27.8,-6.475,-16.380000000000003,-126.025,-171.05,-5.55,-6.025,-6.875,-16.425,-9.525,-16.475,-28.65,-42.7,-5.55,-2.35,-8.75,-40.95,-5.15,-5.9,-10.725,-27.8,-6.475,-16.380000000000003 ...

# %%
# exportar fig as html
fig.write_html("Cohesiveness_Times_Bold.html")

# %% [markdown]
# # Subset Index of viscosity

# %%
# Import data
df = pd.read_excel('gumts.xlsx')

# Remove of specified columns
df = df.drop(df.columns[[0, 4, 5, 11, 12, 13]], axis=1)

# Select predictors and firmness response
df = df.iloc[:, [0, 1, 2, 6]]

# Columns rename
df.columns = ["time", "gum", "concent", "index"]
# Out:
# Index(['time', 'Gum', 'Concent', 'Index of Viscosity (g.sec)'], dtype='object')

# %%
# df head
print(df.head())
# Out:
#    time  gum  concent  index
# 0     0  xan     0.50  -15.4
# 1     0  xan     0.50  -15.4
# 2     0  xan     1.25  -88.3
# 3     0  xan     1.25  -88.6
# 4     0  xan     2.25 -244.5

# %%
# Remove specific observations
df = df[~df['gum'].isin(["Dextrose+xant", "Honey+xant"])]
df['gum'].unique()
# Out:
# array(['xan', 'gua', 'loc', 'car', 'gel'], dtype=object)

# %%
# Pivoting DataFrame
pivot_df = df.pivot_table(index=['gum', 'concent'],
                           columns='time',
                           values='index').reset_index()
pivot_df.head()
# Out:
# time  gum  concent        0        1           2           3
# 0     car     0.50   -4.615   -4.825   -4.700000   -3.500000
# 1     car     1.25   -6.900   -4.225   -4.600000   -3.366667
# 2     car     2.25  -53.800  -17.350   -8.766667   -7.500000
# 3     car     3.00 -439.050 -259.800 -318.533333 -199.900000
# 4     gel     0.50   -4.400   -4.025   -5.566667   -3.266667

# %%
print("Columns in pivot_df:", pivot_df.columns.tolist())
# Out:
# Columns in pivot_df: ['gum', 'concent', 0, 1, 2, 3]

# %%
# Rename columns '0', '1', '2', '3' a 't0', 't1', 't2', 't3'
pivot_df.rename(columns={0: 't0', 1: 't1', 2: 't2', 3: 't3'}, inplace=True)

# DataFrame Head
print(pivot_df.head())
# Out:
# time  gum  concent       t0       t1          t2          t3
# 0     car     0.50   -4.615   -4.825   -4.700000   -3.500000
# 1     car     1.25   -6.900   -4.225   -4.600000   -3.366667
# 2     car     2.25  -53.800  -17.350   -8.766667   -7.500000
# 3     car     3.00 -439.050 -259.800 -318.533333 -199.900000
# 4     gel     0.50   -4.400   -4.025   -5.566667   -3.266667

# %%
pivot_df['gum_code'] = pivot_df['gum'].astype('category').cat.codes

# %%
# adding 5 unique category codes for 'gum'
unique_categories = pivot_df['gum'].unique()
desired_codes = [0, 0.2, 0.4, 0.6, 0.8]

# Mapping category codes
mapping_dict = dict(zip(unique_categories, desired_codes))

# Apply mapping to 'gum_code'
pivot_df['gum_code'] = pivot_df['gum'].map(mapping_dict)

# show
pivot_df
# Out:
# time  gum  concent        t0         t1           t2          t3  gum_code
# 0     car     0.50    -4.615    -4.8250    -4.700000   -3.500000       0.0
# 1     car     1.25    -6.900    -4.2250    -4.600000   -3.366667       0.0
# 2     car     2.25   -53.800   -17.3500    -8.766667   -7.500000       0.0
# 3     car     3.00  -439.050  -259.8000  -318.533333 -199.900000       0.0
# 4     gel     0.50    -4.400    -4.0250    -5.566667   -3.266667       0.2
# 5     gel     1.25    -8.750    -5.9250    -5.766667   -4.066667       0.2
# 6     gel     2.25  -111.400   -39.6750   -22.766667  -32.100000       0.2
# 7     gel     3.00  -336.750  -199.3500  -122.333333 -204.933333       0.2
# 8     gua     0.50    -6.665    -6.9575    -7.433333  -12.266667       0.4
# 9     gua     1.25   -52.400  -105.5000   -60.466667  -11.800000       0.4
# 10    gua     2.25  -980.200  -953.0000  -866.233333 -255.400000       0.4
# 11    gua     3.00 -1164.300 -1404.9250 -1147.033333 -403.433333       0.4
# 12    loc     0.50    -4.835    -4.7750    -3.966667   -3.533333       0.6
# 13    loc     1.25    -5.800    -6.3500    -4.933333   -4.766667       0.6
# 14    loc     2.25   -12.550    -9.6250    -7.966667  -57.833333       0.6
# 15    loc     3.00   -58.900  -112.3250   -67.500000  -25.166667       0.6
# 16    xan     0.50   -15.400   -17.5750   -17.533333  -12.133333       0.8
# 17    xan     1.25   -88.450   -79.2500   -79.766667  -56.133333       0.8
# 18    xan     2.25  -240.450  -220.3500  -208.266667 -158.033333       0.8
# 19    xan     3.00  -357.950  -349.8000  -335.366667 -241.900000       0.8

# %%
# Repeat the DataFrame 10 times to make plot lines bolder
pivot_df = pd.concat([pivot_df] * 10, ignore_index=True)

# Display the result
pivot_df
# Out:
# time  gum  concent       t0       t1          t2          t3  gum_code
# 0     car     0.50   -4.615   -4.825   -4.700000   -3.500000       0.0
# 1     car     1.25   -6.900   -4.225   -4.600000   -3.366667       0.0
# 2     car     2.25  -53.800  -17.350   -8.766667   -7.500000       0.0
# 3     car     3.00 -439.050 -259.800 -318.533333 -199.900000       0.0
# 4     gel     0.50   -4.400   -4.025   -5.566667   -3.266667       0.2
# ..    ...      ...      ...      ...         ...         ...       ...
# 195   loc     3.00  -58.900 -112.325  -67.500000  -25.166667       0.6
# 196   xan     0.50  -15.400  -17.575  -17.533333  -12.133333       0.8
# 197   xan     1.25  -88.450  -79.250  -79.766667  -56.133333       0.8
# 198   xan     2.25 -240.450 -220.350 -208.266667 -158.033333       0.8
# 199   xan     3.00 -357.950 -349.800 -335.366667 -241.900000       0.8
#
# [200 rows x 7 columns]

# %% [markdown]
# ### Plotting

# %%
fig = go.Figure(data=
    go.Parcoords(
        line = dict(color = pivot_df['gum_code'],
                   colorscale = "Tealrose"),
        dimensions = list([
            dict(range = [0.5, 3],
                label = 'Gum Concentration (%)', values = pivot_df['concent']),
            dict(range = [-1410, -3],
                label = 'Time 0', values = pivot_df['t0']),
            dict(range = [-1410, -3],
                label = 'Time 1', values = pivot_df['t1']),
            dict(range = [-1410, -3],
                label = 'Time 2', values = pivot_df['t2']),
            dict(range = [-1410, -3],
                label = 'Time 3', values = pivot_df['t3']),
        ])
    )
)

fig.update_layout(
    plot_bgcolor = 'white',
    paper_bgcolor = 'white',
    title_text="Index of viscosity (g/s) of gums tested over time"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c5017d29-b6d9-4759-8fee-2d9ddd6692d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c5017d29-b6d9-4759-8fee-2d9ddd6692d9")) {                    Plotly.newPlot(                        "c5017d29-b6d9-4759-8fee-2d9ddd6692d9",                        [{"dimensions":[{"label":"Gum Concentration (%)","range":[0.5,3],"values":[0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0,0.5,1.25,2.25,3.0]},{"label":"Time 0","range":[-1410,-3],"values":[-4.615,-6.9,-53.8,-439.04999999999995,-4.4,-8.75,-111.4,-336.75,-6.665,-52.400000000000006,-980.1999999999999,-1164.3,-4.835,-5.800000000000001,-12.55,-58.9,-15.4,-88.44999999999999,-240.45,-357.95,-4.615,-6.9,-53.8,-439.04999999999995,-4.4,-8.75,-111.4,-336.75,-6.665,-52.400000000000006,-980.1999999999999,-1164.3,-4.835,-5.800000000000001,-12.55,-58.9,-15.4,-88.44999999999999,-240.45,-357.95,-4.615,-6.9,-53.8,-439.04999999999995,-4.4,-8.75,-111.4,-336.75,-6.665,-52.400000000000006,-980.1999999999999,-1164.3,-4.835,-5.800000000000001,-12.55,-58.9,-15.4,-88.44999999999999,-240.45,-357.95,-4.615,-6.9,-53.8,-439.04999999999995,-4.4,-8.75,-111.4,-336.75,-6.665,-52.400000000000006,-980.1999999999999,-1164.3,-4.835,-5.800000000000001,-12.55,-58.9,-15.4,-88.44999999999999,-240.45,-357.95,-4.615,-6.9,-53.8,-439.04999999999995,-4.4,-8.75,-111.4,-336.75,-6.665,-52.400000000000006,-980.1999999999999,-1164.3,-4.835,-5.800000000000001,-12.55,-58.9,-15.4,-88.44999999999999,-240.45,-357.95,-4.615,-6.9,-53.8,-439.04999999999995,-4.4,-8.75,-111.4,-336.75,-6.665,-52.400000000000006,-980.1999999999999,-1164.3,-4.835,-5.800000000000001,-12.55,-58.9,-15.4,-88.44999999999999,-240.45,-357.95,-4.615,-6.9,-53.8,-439.04999999999995,-4.4,-8.75,-111.4,-336.75,-6.665,-52.400000000000006,-980.1999999999999,-1164.3,-4.835,-5.800000000000001,-12.55,-58.9,-15.4,-88.44999999999999,-240.45,-357.95,-4.615,-6.9,-53.8,-439.04999999999995,-4.4,-8.75,-111.4,-336.75,-6.665,-52.400000000000006,-980.1999999999999,-1164.3,-4.835,-5.800000000000001,-12.55,-58.9,-15.4,-88.44999999999999,-240.45,-357.95,-4.615,-6.9,-53.8,-439.04999999999995,-4.4,-8.75,-111.4,-336.75,-6.665,-52.400000000000006,-980.1999999999999,-1164.3,-4.835,-5.800000000000001,-12.55,-58.9,-15.4,-88.44999999999999,-240.45,-357.95,-4.615,-6.9,-53.8,-439.04999999999995,-4.4,-8.75,-111.4,-336.75,-6.665,-52.400000000000006,-980.1999999999999,-1164.3,-4.835,-5.800000000000001,-12.55,-58.9,-15.4,-88.44999999999999,-240.45,-357.95]},{"label":"Time 1","range":[-1410,-3],"values":[-4.825,-4.225,-17.35,-259.8,-4.025,-5.925,-39.675,-199.35,-6.9575,-105.5,-953.0,-1404.925,-4.775,-6.35,-9.625,-112.325,-17.575,-79.25,-220.35000000000002,-349.8,-4.825,-4.225,-17.35,-259.8,-4.025,-5.925,-39.675,-199.35,-6.9575,-105.5,-953.0,-1404.925,-4.775,-6.35,-9.625,-112.325,-17.575,-79.25,-220.35000000000002,-349.8,-4.825,-4.225,-17.35,-259.8,-4.025,-5.925,-39.675,-199.35,-6.9 ...

# %%
# exportar fig as html
fig.write_html("Index_Times_Bold.html")

# %% [markdown]
# # Subset Viscosity

# %%
# Import data
df = pd.read_excel('gumts.xlsx')

# Remove of specified columns
df = df.drop(df.columns[[0, 4, 5, 11, 12, 13]], axis=1)

# Select predictors and firmness response
df = df.iloc[:, [0, 1, 2, 7]]

# Columns rename
df.columns = ["time", "gum", "concent", "viscosity"]
# Out:
# Index(['time', 'Gum', 'Concent', 'viscosity (mPa.s) '], dtype='object')

# %%
# df head
print(df.head())
# Out:
#    time  gum  concent viscosity
# 0     0  xan     0.50      33.4
# 1     0  xan     0.50        43
# 2     0  xan     1.25      67.4
# 3     0  xan     1.25      71.9
# 4     0  xan     2.25       191

# %%
# Remove specific observations
df = df[~df['gum'].isin(["Dextrose+xant", "Honey+xant"])]
df = df[~df['viscosity'].isin(["too high"])]
df['gum'].unique()
# Out:
# array(['xan', 'gua', 'loc', 'car', 'gel'], dtype=object)

# %%
# Pivoting DataFrame
pivot_df = df.pivot_table(index=['gum', 'concent'],
                           columns='time',
                           values='viscosity').reset_index()
pivot_df.head()
# Out:
# time  gum  concent      0       1           2          3
# 0     car     0.50   14.4    9.55   19.766667       11.1
# 1     car     1.25   23.7  25.925   27.833333  33.133333
# 2     car     2.25  236.0  131.75   60.233333  70.566667
# 3     car     3.00  946.7     NaN  395.733333        9.2
# 4     gel     0.50  11.55    10.6    6.593333        9.2

# %%
print("Columns in pivot_df:", pivot_df.columns.tolist())
# Out:
# Columns in pivot_df: ['gum', 'concent', 0, 1, 2, 3]

# %%
# Rename columns '0', '1', '2', '3' a 't0', 't1', 't2', 't3'
pivot_df.rename(columns={0: 't0', 1: 't1', 2: 't2', 3: 't3'}, inplace=True)

# DataFrame Head
print(pivot_df.head())
# Out:
# time  gum  concent     t0      t1          t2         t3
# 0     car     0.50   14.4    9.55   19.766667       11.1
# 1     car     1.25   23.7  25.925   27.833333  33.133333
# 2     car     2.25  236.0  131.75   60.233333  70.566667
# 3     car     3.00  946.7     NaN  395.733333        9.2
# 4     gel     0.50  11.55    10.6    6.593333        9.2

# %%
pivot_df['gum_code'] = pivot_df['gum'].astype('category').cat.codes

# %%
# adding 5 unique category codes for 'gum'
unique_categories = pivot_df['gum'].unique()
desired_codes = [0, 0.2, 0.4, 0.6, 0.8]

# Mapping category codes
mapping_dict = dict(zip(unique_categories, desired_codes))

# Apply mapping to 'gum_code'
pivot_df['gum_code'] = pivot_df['gum'].map(mapping_dict)

# show
pivot_df
# Out:
# time  gum  concent     t0      t1          t2          t3  gum_code
# 0     car     0.50   14.4    9.55   19.766667        11.1       0.0
# 1     car     1.25   23.7  25.925   27.833333   33.133333       0.0
# 2     car     2.25  236.0  131.75   60.233333   70.566667       0.0
# 3     car     3.00  946.7     NaN  395.733333         9.2       0.0
# 4     gel     0.50  11.55    10.6    6.593333         9.2       0.2
# 5     gel     1.25   35.7    19.3   30.533333        19.0       0.2
# 6     gel     2.25  141.0   124.5  101.133333   98.666667       0.2
# 7     gel     3.00  295.5  271.25  198.666667  198.666667       0.2
# 8     gua     0.50  25.85  28.775        37.0        23.2       0.4
# 9     gua     1.25  172.0  331.25  167.166667   41.366667       0.4
# 10    loc     0.50   9.15   13.95    8.366667   14.433333       0.6
# 11    loc     1.25  22.05   38.85   27.866667   37.933333       0.6
# 12    loc     2.25  153.0   187.5  274.666667  135.033333       0.6
# 13    loc     3.00  517.5   517.5         NaN       463.0       0.6
# 14    xan     0.50   38.2  36.625   34.666667   38.533333       0.8
# 15    xan     1.25  69.65    69.6   58.766667        63.3       0.8
# 16    xan     2.25  202.5   153.0  137.666667   91.466667       0.8
# 17    xan     3.00  468.5   273.5       232.0  160.666667       0.8

# %%
pivot_df = pivot_df.dropna()
pivot_df
# Out:
# time  gum  concent     t0      t1          t2          t3  gum_code
# 0     car     0.50   14.4    9.55   19.766667        11.1       0.0
# 1     car     1.25   23.7  25.925   27.833333   33.133333       0.0
# 2     car     2.25  236.0  131.75   60.233333   70.566667       0.0
# 4     gel     0.50  11.55    10.6    6.593333         9.2       0.2
# 5     gel     1.25   35.7    19.3   30.533333        19.0       0.2
# 6     gel     2.25  141.0   124.5  101.133333   98.666667       0.2
# 7     gel     3.00  295.5  271.25  198.666667  198.666667       0.2
# 8     gua     0.50  25.85  28.775        37.0        23.2       0.4
# 9     gua     1.25  172.0  331.25  167.166667   41.366667       0.4
# 10    loc     0.50   9.15   13.95    8.366667   14.433333       0.6
# 11    loc     1.25  22.05   38.85   27.866667   37.933333       0.6
# 12    loc     2.25  153.0   187.5  274.666667  135.033333       0.6
# 14    xan     0.50   38.2  36.625   34.666667   38.533333       0.8
# 15    xan     1.25  69.65    69.6   58.766667        63.3       0.8
# 16    xan     2.25  202.5   153.0  137.666667   91.466667       0.8
# 17    xan     3.00  468.5   273.5       232.0  160.666667       0.8

# %%
# Repeat the DataFrame 10 times to make plot lines bolder
pivot_df = pd.concat([pivot_df] * 10, ignore_index=True)

# Display the result
pivot_df
# Out:
# time  gum  concent     t0      t1          t2          t3  gum_code
# 0     car     0.50   14.4    9.55   19.766667        11.1       0.0
# 1     car     1.25   23.7  25.925   27.833333   33.133333       0.0
# 2     car     2.25  236.0  131.75   60.233333   70.566667       0.0
# 3     gel     0.50  11.55    10.6    6.593333         9.2       0.2
# 4     gel     1.25   35.7    19.3   30.533333        19.0       0.2
# ..    ...      ...    ...     ...         ...         ...       ...
# 155   loc     2.25  153.0   187.5  274.666667  135.033333       0.6
# 156   xan     0.50   38.2  36.625   34.666667   38.533333       0.8
# 157   xan     1.25  69.65    69.6   58.766667        63.3       0.8
# 158   xan     2.25  202.5   153.0  137.666667   91.466667       0.8
# 159   xan     3.00  468.5   273.5       232.0  160.666667       0.8
#
# [160 rows x 7 columns]

# %% [markdown]
# ### Plotting

# %%
fig = go.Figure(data=
    go.Parcoords(
        line = dict(color = pivot_df['gum_code'],
                   colorscale = "Plasma"),
        dimensions = list([
            dict(range = [0.5, 3],
                label = 'Gum Concentration (%)', values = pivot_df['concent']),
            dict(range = [5, 500],
                label = 'Time 0', values = pivot_df['t0']),
            dict(range = [5, 500],
                label = 'Time 1', values = pivot_df['t1']),
            dict(range = [5, 500],
                label = 'Time 2', values = pivot_df['t2']),
            dict(range = [5, 500],
                label = 'Time 3', values = pivot_df['t3']),
        ])
    )
)

fig.update_layout(
    plot_bgcolor = 'white',
    paper_bgcolor = 'white',
    title_text="Viscosity (mPa/s) of gums tested over time"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="409a0f80-70db-4667-9683-1ada07bfdd26" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("409a0f80-70db-4667-9683-1ada07bfdd26")) {                    Plotly.newPlot(                        "409a0f80-70db-4667-9683-1ada07bfdd26",                        [{"dimensions":[{"label":"Gum Concentration (%)","range":[0.5,3],"values":[0.5,1.25,2.25,0.5,1.25,2.25,3.0,0.5,1.25,0.5,1.25,2.25,0.5,1.25,2.25,3.0,0.5,1.25,2.25,0.5,1.25,2.25,3.0,0.5,1.25,0.5,1.25,2.25,0.5,1.25,2.25,3.0,0.5,1.25,2.25,0.5,1.25,2.25,3.0,0.5,1.25,0.5,1.25,2.25,0.5,1.25,2.25,3.0,0.5,1.25,2.25,0.5,1.25,2.25,3.0,0.5,1.25,0.5,1.25,2.25,0.5,1.25,2.25,3.0,0.5,1.25,2.25,0.5,1.25,2.25,3.0,0.5,1.25,0.5,1.25,2.25,0.5,1.25,2.25,3.0,0.5,1.25,2.25,0.5,1.25,2.25,3.0,0.5,1.25,0.5,1.25,2.25,0.5,1.25,2.25,3.0,0.5,1.25,2.25,0.5,1.25,2.25,3.0,0.5,1.25,0.5,1.25,2.25,0.5,1.25,2.25,3.0,0.5,1.25,2.25,0.5,1.25,2.25,3.0,0.5,1.25,0.5,1.25,2.25,0.5,1.25,2.25,3.0,0.5,1.25,2.25,0.5,1.25,2.25,3.0,0.5,1.25,0.5,1.25,2.25,0.5,1.25,2.25,3.0,0.5,1.25,2.25,0.5,1.25,2.25,3.0,0.5,1.25,0.5,1.25,2.25,0.5,1.25,2.25,3.0]},{"label":"Time 0","range":[5,500],"values":[14.4,23.700000000000003,236.0,11.55,35.7,141.0,295.5,25.85,172.0,9.15,22.05,153.0,38.2,69.65,202.5,468.5,14.4,23.700000000000003,236.0,11.55,35.7,141.0,295.5,25.85,172.0,9.15,22.05,153.0,38.2,69.65,202.5,468.5,14.4,23.700000000000003,236.0,11.55,35.7,141.0,295.5,25.85,172.0,9.15,22.05,153.0,38.2,69.65,202.5,468.5,14.4,23.700000000000003,236.0,11.55,35.7,141.0,295.5,25.85,172.0,9.15,22.05,153.0,38.2,69.65,202.5,468.5,14.4,23.700000000000003,236.0,11.55,35.7,141.0,295.5,25.85,172.0,9.15,22.05,153.0,38.2,69.65,202.5,468.5,14.4,23.700000000000003,236.0,11.55,35.7,141.0,295.5,25.85,172.0,9.15,22.05,153.0,38.2,69.65,202.5,468.5,14.4,23.700000000000003,236.0,11.55,35.7,141.0,295.5,25.85,172.0,9.15,22.05,153.0,38.2,69.65,202.5,468.5,14.4,23.700000000000003,236.0,11.55,35.7,141.0,295.5,25.85,172.0,9.15,22.05,153.0,38.2,69.65,202.5,468.5,14.4,23.700000000000003,236.0,11.55,35.7,141.0,295.5,25.85,172.0,9.15,22.05,153.0,38.2,69.65,202.5,468.5,14.4,23.700000000000003,236.0,11.55,35.7,141.0,295.5,25.85,172.0,9.15,22.05,153.0,38.2,69.65,202.5,468.5]},{"label":"Time 1","range":[5,500],"values":[9.55,25.924999999999997,131.75,10.6,19.3,124.5,271.25,28.775,331.25,13.95,38.85,187.5,36.625,69.6,153.0,273.5,9.55,25.924999999999997,131.75,10.6,19.3,124.5,271.25,28.775,331.25,13.95,38.85,187.5,36.625,69.6,153.0,273.5,9.55,25.924999999999997,131.75,10.6,19.3,124.5,271.25,28.775,331.25,13.95,38.85,187.5,36.625,69.6,153.0,273.5,9.55,25.924999999999997,131.75,10.6,19.3,124.5,271.25,28.775,331.25,13.95,38.85,187.5,36.625,69.6,153.0,273.5,9.55,25.924999999999997,131.75,10.6,19.3,124.5,271.25,28.775,331.25,13.95,38.85,187.5,36.625,69.6,153.0,273.5,9.55,25.924999999999997,131.75,10.6,19.3,124.5,271.25,28.775,331.25,13.95,38.85,187.5,36.625,69.6,153.0,273.5,9.55,25.924999999999997,131.75,10.6,19.3,124.5,271.25,28.775,331.25,13.95,38.85,187.5,36.625,69.6,153.0,273.5,9.55,25.924999999999997,131.75,10.6,19.3,124.5,271.25,28.775,331.25,13.95,38.85,187.5,36.625,69.6,153.0,273.5,9.55,25.924999999999997,131.75,10.6,19.3,124.5,271.25,28.775,331.25,13.95,38.85,187.5,36.625,69.6,153.0,273.5,9.55,25.924999999999997,131.75,10.6,19.3,124.5,271.25,28.775,331.25,13.95,38.85,187.5,36.625,69.6,153.0,273.5]},{"label":"Time 2","range":[5,500],"values":[19.766666666666666,27.833333333333332,60.23333333333333,6.593333333333334,30.53333333333333,101.13333333333333,198.66666666666666,37.0,167.16666666666666,8.366666666666667,27.866666666666664,274.6666666666667,34.666666666666664,58.76666666666667,137.66666666666666,232.0,19.766666666666666,27.833333333333332,60.23333333333333,6.593333333333334 ...

# %%
# exportar fig as html
fig.write_html("Viscosity_Times_Bold.html")
